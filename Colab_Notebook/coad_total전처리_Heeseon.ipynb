# %% [markdown]
# <a href="https://colab.research.google.com/github/hansuho113/SwUniv_CancerAnalysis/blob/main/Colab_Notebook/coad_total%EC%A0%84%EC%B2%98%EB%A6%AC_Heeseon.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
total = pd.read_excel("/content/drive/MyDrive/2021캡스톤/coad_total.xlsx")
total
# Out:
#     bcr_patient_barcode  ... tumor_status
# 0          TCGA-3L-AA1B  ...   TUMOR FREE
# 1          TCGA-4N-A93T  ...   WITH TUMOR
# 2          TCGA-4T-AA8H  ...   TUMOR FREE
# 3          TCGA-5M-AAT4  ...   WITH TUMOR
# 4          TCGA-5M-AAT6  ...   WITH TUMOR
# ..                  ...  ...          ...
# 454        TCGA-QL-A97D  ...   TUMOR FREE
# 455        TCGA-RU-A8FL  ...   WITH TUMOR
# 456        TCGA-SS-A7HO  ...   WITH TUMOR
# 457        TCGA-T9-A92H  ...   WITH TUMOR
# 458        TCGA-WS-AB45  ...   TUMOR FREE
#
# [459 rows x 86 columns]

# %%
total['histological_grade'].value_counts()
# Out:
# [Not Available]    459
# Name: histological_grade, dtype: int64

# %%
total_d = total.drop(['clinical_M', 'clinical_stage', 'histological_grade'], axis=1)
display(total_d)
# Out:
#     bcr_patient_barcode  ... tumor_status
# 0          TCGA-3L-AA1B  ...   TUMOR FREE
# 1          TCGA-4N-A93T  ...   WITH TUMOR
# 2          TCGA-4T-AA8H  ...   TUMOR FREE
# 3          TCGA-5M-AAT4  ...   WITH TUMOR
# 4          TCGA-5M-AAT6  ...   WITH TUMOR
# ..                  ...  ...          ...
# 454        TCGA-QL-A97D  ...   TUMOR FREE
# 455        TCGA-RU-A8FL  ...   WITH TUMOR
# 456        TCGA-SS-A7HO  ...   WITH TUMOR
# 457        TCGA-T9-A92H  ...   WITH TUMOR
# 458        TCGA-WS-AB45  ...   TUMOR FREE
#
# [459 rows x 83 columns]

# %%
res = pd.read_csv("/content/drive/MyDrive/2021캡스톤/drug_response_COAD.csv")
res = res.drop(['Unnamed: 0', 'Cancer Type'], axis=1)
res
# Out:
#     bcr_patient_barcode  ...                     therapy_types
# 0          TCGA-D5-5539  ...                      Chemotherapy
# 1          TCGA-A6-6648  ...                               NaN
# 2          TCGA-A6-6648  ...                               NaN
# 3          TCGA-A6-6648  ...                               NaN
# 4          TCGA-AA-3560  ...                      Chemotherapy
# ..                  ...  ...                               ...
# 537        TCGA-A6-2674  ...  Other, specify in notesancillary
# 538        TCGA-A6-2674  ...        Targeted Molecular therapy
# 539        TCGA-A6-2674  ...                      Chemotherapy
# 540        TCGA-A6-2674  ...                      Chemotherapy
# 541        TCGA-A6-2674  ...                      Chemotherapy
#
# [542 rows x 7 columns]

# %%
total_res = res.merge(total_d, on=['bcr_patient_barcode'],
     how='inner').drop_duplicates(['bcr_patient_barcode'],keep= 'first').reset_index(drop=True)
display(total_res)
# Out:
#     bcr_patient_barcode  ... tumor_status
# 0          TCGA-D5-5539  ...   WITH TUMOR
# 1          TCGA-A6-6648  ...   WITH TUMOR
# 2          TCGA-AA-3560  ...   TUMOR FREE
# 3          TCGA-AZ-4615  ...   WITH TUMOR
# 4          TCGA-AY-6386  ...   TUMOR FREE
# ..                  ...  ...          ...
# 137        TCGA-A6-2671  ...   WITH TUMOR
# 138        TCGA-G4-6315  ...   TUMOR FREE
# 139        TCGA-A6-6651  ...   TUMOR FREE
# 140        TCGA-AA-A00U  ...   TUMOR FREE
# 141        TCGA-A6-2674  ...   TUMOR FREE
#
# [142 rows x 89 columns]
