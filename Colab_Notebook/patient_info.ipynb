# %% [markdown]
# <a href="https://colab.research.google.com/github/hansuho113/SwUniv_CancerAnalysis/blob/main/Colab_Notebook/patient_info.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
patient = pd.read_excel("/content/drive/MyDrive/2021캡스톤/patient_followup.xlsx")
patient
# Out:
#                            bcr_patient_uuid  ... days_to_last_known_alive
# 0      B3164F7B-C826-4E08-9EE6-8FF96D29B913  ...                      NaN
# 1      8E7C2E31-D085-4B75-A970-162526DD07A0  ...                      NaN
# 2      DFD687BC-6E69-42F7-AF94-D17FC150D1A1  ...                      NaN
# 3      5F3E2974-F1DF-47A2-8A8A-29BB525EEEF6  ...                      NaN
# 4      802DBD0D-EF07-4C91-AB8D-1DD39532E947  ...                      NaN
# ...                                     ...  ...                      ...
# 10951  E00CE846-9A0E-48B5-BE9F-84D443A0F78A  ...                      NaN
# 10952  CBA920F4-C57F-47BC-958D-9B7872DF01C8  ...                      NaN
# 10953  DF291BBF-FC62-4C40-9582-289AC78225FD  ...                      NaN
# 10954  743FC661-9BA2-4FA8-966E-508FB4B965E0  ...                      NaN
# 10955  EBDABFCB-1C68-4CA1-8B7F-3EA9CDAC3A6A  ...                      NaN
#
# [10956 rows x 746 columns]

# %%
patient['acronym'].value_counts()
# Out:
# BRCA    1099
# GBM      596
# OV       587
# UCEC     548
# KIRC     537
# HNSC     528
# LUAD     522
# LGG      515
# THCA     507
# LUSC     504
# PRAD     500
# SKCM     471
# COAD     459
# STAD     443
# BLCA     412
# LIHC     377
# CESC     308
# KIRP     291
# SARC     261
# ESCA     185
# PAAD     185
# PCPG     179
# READ     171
# TGCT     134
# THYM     124
# KICH     113
# ACC       92
# MESO      87
# UVM       80
# UCS       57
# DLBC      48
# CHOL      36
# Name: acronym, dtype: int64

# %%
patient_c = patient[patient['acronym'] == "COAD"]
patient_c
# Out:
# info                      bcr_patient_uuid  ... days_to_last_known_alive
# 1947  A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...                      NaN
# 1948  92554413-9EBC-4354-8E1B-9682F3A031D9  ...                      NaN
# 1949  A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...                      NaN
# 1950  1136DD50-242A-4659-AAD4-C53F9E759BB3  ...                      NaN
# 1951  CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...                      NaN
# ...                                    ...  ...                      ...
# 2401  D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...                      NaN
# 2402  5F6ED48B-3B5A-4D20-8FBF-C9AA3FEEA186  ...                      NaN
# 2403  8D0FA506-3F51-4108-8427-7DABF270BCD4  ...                      NaN
# 2404  81A7184E-F9F5-4E3F-9603-5F5642386C1E  ...                      NaN
# 2405  7F6898E2-A840-4AD1-80F7-783F8B766FCC  ...                      NaN
#
# [459 rows x 746 columns]

# %%
patient_dropna = patient_c.dropna(axis=1)
patient_dropna
# Out:
# info                      bcr_patient_uuid  ... loss_expression_of_mismatch_repair_proteins_by_ihc
# 1947  A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...                                                YES
# 1948  92554413-9EBC-4354-8E1B-9682F3A031D9  ...                                                YES
# 1949  A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...                                                YES
# 1950  1136DD50-242A-4659-AAD4-C53F9E759BB3  ...                                                 NO
# 1951  CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...                                                 NO
# ...                                    ...  ...                                                ...
# 2401  D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...                                    [Not Available]
# 2402  5F6ED48B-3B5A-4D20-8FBF-C9AA3FEEA186  ...                                                 NO
# ...

# %%
patient_dropna_f = patient_dropna.replace("[Not Available]","")
patient_dropna_f
# Out:
# info                      bcr_patient_uuid  ... loss_expression_of_mismatch_repair_proteins_by_ihc
# 1947  A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...                                                YES
# 1948  92554413-9EBC-4354-8E1B-9682F3A031D9  ...                                                YES
# 1949  A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...                                                YES
# 1950  1136DD50-242A-4659-AAD4-C53F9E759BB3  ...                                                 NO
# 1951  CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...                                                 NO
# ...                                    ...  ...                                                ...
# 2401  D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...
# 2402  5F6ED48B-3B5A-4D20-8FBF-C9AA3FEEA186  ...                                                 NO
# 2403  8D0FA506-3F51-4108-8427-7DABF270BCD4  ...                                                 NO
# ...

# %%
patient_dropna_f.replace('', np.nan, inplace=True)
patient_dropna_f
# Out:
# info                      bcr_patient_uuid  ... loss_expression_of_mismatch_repair_proteins_by_ihc
# 1947  A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...                                                YES
# 1948  92554413-9EBC-4354-8E1B-9682F3A031D9  ...                                                YES
# 1949  A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...                                                YES
# 1950  1136DD50-242A-4659-AAD4-C53F9E759BB3  ...                                                 NO
# 1951  CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...                                                 NO
# ...                                    ...  ...                                                ...
# 2401  D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...                                                NaN
# 2402  5F6ED48B-3B5A-4D20-8FBF-C9AA3FEEA186  ...                                                 NO
# ...

# %%
patient_dropnot = patient_dropna_f.dropna(axis=1)
patient_dropnot
#이렇게 했더니 [Not Available]만 포함되어 있는 열뿐만 아니라 [Not Available]이 포함된 열도 함께 제거됨
#[Not Available]로만 이루어진 열만 삭제하는 방법은 열 하나하나 찾아서 제거하는 방법 외에 모르겠음..
# Out:
# info                      bcr_patient_uuid  ... extranodal_involvement
# 1947  A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...       [Not Applicable]
# 1948  92554413-9EBC-4354-8E1B-9682F3A031D9  ...       [Not Applicable]
# 1949  A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...       [Not Applicable]
# 1950  1136DD50-242A-4659-AAD4-C53F9E759BB3  ...       [Not Applicable]
# 1951  CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...       [Not Applicable]
# ...                                    ...  ...                    ...
# 2401  D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...       [Not Applicable]
# 2402  5F6ED48B-3B5A-4D20-8FBF-C9AA3FEEA186  ...       [Not Applicable]
# 2403  8D0FA506-3F51-4108-8427-7DABF270BCD4  ...       [Not Applicable]
# 2404  81A7184E-F9F5-4E3F-9603-5F5642386C1E  ...       [Not Applicable]
# 2405  7F6898E2-A840-4AD1-80F7-783F8B766FCC  ...       [Not Applicable]
#
# [459 rows x 22 columns]

# %%
patient_dropnot.columns
# Out:
# Index(['bcr_patient_uuid', 'bcr_patient_barcode', 'acronym', 'gender',
#        'vital_status', 'days_to_death', 'days_to_initial_pathologic_diagnosis',
#        'age_at_initial_pathologic_diagnosis',
#        'history_of_neoadjuvant_treatment', 'prior_dx',
#        'informed_consent_verified', 'patient_id',
#        'year_of_initial_pathologic_diagnosis', 'tissue_source_site',
#        'form_completion_date', 'pathologic_T', 'clinical_M', 'pathologic_N',
#        'clinical_stage', 'clinical_T', 'clinical_N', 'extranodal_involvement'],
#       dtype='object', name='info')
