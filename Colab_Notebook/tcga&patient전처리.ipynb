# %% [markdown]
# <a href="https://colab.research.google.com/github/hansuho113/SwUniv_CancerAnalysis/blob/main/Colab_Notebook/tcga%26patient%EC%A0%84%EC%B2%98%EB%A6%AC.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
patient = pd.read_excel("/content/drive/MyDrive/2021캡스톤/patient_followup_COAD_1.xlsx")
patient
# Out:
#      Unnamed: 0  ... loss_expression_of_mismatch_repair_proteins_by_ihc
# 0          1947  ...                                                YES
# 1          1948  ...                                                YES
# 2          1949  ...                                                YES
# 3          1950  ...                                                 NO
# 4          1951  ...                                                 NO
# ..          ...  ...                                                ...
# 454        2401  ...                                    [Not Available]
# 455        2402  ...                                                 NO
# 456        2403  ...                                                 NO
# 457        2404  ...                                                 NO
# 458        2405  ...                                                YES
#
# [459 rows x 69 columns]

# %%
tcga = pd.read_excel("/content/drive/MyDrive/2021캡스톤/TCGA_CDR.xlsx")
tcga
# Out:
#       bcr_patient_barcode type  ...  PFI PFI.time
# 0            TCGA-OR-A5J1  ACC  ...  1.0    754.0
# 1            TCGA-OR-A5J2  ACC  ...  1.0    289.0
# 2            TCGA-OR-A5J3  ACC  ...  1.0     53.0
# 3            TCGA-OR-A5J4  ACC  ...  1.0    126.0
# 4            TCGA-OR-A5J5  ACC  ...  1.0     50.0
# ...                   ...  ...  ...  ...      ...
# 11155        TCGA-YZ-A980  UVM  ...  1.0   1556.0
# 11156        TCGA-YZ-A982  UVM  ...  0.0    495.0
# 11157        TCGA-YZ-A983  UVM  ...  0.0    798.0
# 11158        TCGA-YZ-A984  UVM  ...  1.0    154.0
# 11159        TCGA-YZ-A985  UVM  ...  0.0   1184.0
#
# [11160 rows x 24 columns]

# %%
tcga_c = tcga[tcga['type'] == "COAD"]
tcga_c
# Out:
#      bcr_patient_barcode  type  ...  PFI PFI.time
# 1953        TCGA-3L-AA1B  COAD  ...  0.0    475.0
# 1954        TCGA-4N-A93T  COAD  ...  0.0    146.0
# 1955        TCGA-4T-AA8H  COAD  ...  0.0    385.0
# 1956        TCGA-5M-AAT4  COAD  ...  1.0     49.0
# 1957        TCGA-5M-AAT6  COAD  ...  1.0    219.0
# ...                  ...   ...  ...  ...      ...
# 2407        TCGA-QL-A97D  COAD  ...  0.0    666.0
# 2408        TCGA-RU-A8FL  COAD  ...  1.0    256.0
# 2409        TCGA-SS-A7HO  COAD  ...  1.0    506.0
# 2410        TCGA-T9-A92H  COAD  ...  1.0     81.0
# 2411        TCGA-WS-AB45  COAD  ...  0.0   2130.0
#
# [459 rows x 24 columns]

# %%
patient.columns
# Out:
# Index(['Unnamed: 0', 'bcr_patient_uuid', 'bcr_patient_barcode', 'acronym',
#        'gender', 'vital_status', 'days_to_birth', 'days_to_death',
#        'days_to_last_followup', 'days_to_initial_pathologic_diagnosis',
#        'age_at_initial_pathologic_diagnosis', 'icd_10',
#        'tissue_retrospective_collection_indicator', 'icd_o_3_histology',
#        'tissue_prospective_collection_indicator',
#        'history_of_neoadjuvant_treatment', 'icd_o_3_site', 'tumor_tissue_site',
#        'new_tumor_event_after_initial_treatment', 'radiation_therapy', 'race',
#        'project_code', 'prior_dx', 'disease_code', 'ethnicity',
#        'informed_consent_verified', 'person_neoplasm_cancer_status',
#        'patient_id', 'year_of_initial_pathologic_diagnosis',
#        'histological_type', 'tissue_source_site', 'form_completion_date',
#        'pathologic_T', 'pathologic_M', 'clinical_M', 'pathologic_N',
#        'system_version', 'pathologic_stage', 'postoperative_rx_tx',
# ...

# %%
tcga_c.columns
# Out:
# Index(['bcr_patient_barcode', 'type', 'age_at_initial_pathologic_diagnosis',
#        'gender', 'ajcc_pathologic_tumor_stage', 'clinical_stage',
#        'histological_grade', 'initial_pathologic_dx_year', 'birth_days_to',
#        'vital_status', 'tumor_status', 'last_contact_days_to', 'death_days_to',
#        'new_tumor_event_type', 'new_tumor_event_dx_days_to',
#        'treatment_outcome_first_course', 'OS', 'OS.time', 'DSS', 'DSS.time',
#        'DFI', 'DFI.time', 'PFI', 'PFI.time'],
#       dtype='object')

# %%
patient.index = patient['bcr_patient_barcode']
patient = patient.drop(['bcr_patient_barcode','Unnamed: 0', 'acronym'], axis=1)
display(patient)
# Out:
#                                          bcr_patient_uuid  ... loss_expression_of_mismatch_repair_proteins_by_ihc
# bcr_patient_barcode                                        ...
# TCGA-3L-AA1B         A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...                                                YES
# TCGA-4N-A93T         92554413-9EBC-4354-8E1B-9682F3A031D9  ...                                                YES
# TCGA-4T-AA8H         A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...                                                YES
# TCGA-5M-AAT4         1136DD50-242A-4659-AAD4-C53F9E759BB3  ...                                                 NO
# TCGA-5M-AAT6         CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...                                                 NO
# ...                                                   ...  ...                                                ...
# TCGA-QL-A97D         D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...                                    [Not Available]
# ...

# %%
tcga_c.index = tcga_c['bcr_patient_barcode']
tcga_c = tcga_c.drop(['bcr_patient_barcode', 'type'], axis=1)
display(tcga_c)
# Out:
#                      age_at_initial_pathologic_diagnosis  gender  ...  PFI PFI.time
# bcr_patient_barcode                                               ...
# TCGA-3L-AA1B                                        61.0  FEMALE  ...  0.0    475.0
# TCGA-4N-A93T                                        67.0    MALE  ...  0.0    146.0
# TCGA-4T-AA8H                                        42.0  FEMALE  ...  0.0    385.0
# TCGA-5M-AAT4                                        74.0    MALE  ...  1.0     49.0
# TCGA-5M-AAT6                                        40.0  FEMALE  ...  1.0    219.0
# ...                                                  ...     ...  ...  ...      ...
# TCGA-QL-A97D                                        84.0  FEMALE  ...  0.0    666.0
# TCGA-RU-A8FL                                        51.0    MALE  ...  1.0    256.0
# TCGA-SS-A7HO                                        44.0  FEMALE  ...  1.0    506.0
# ...

# %%
tcga_m = tcga_c.columns.difference(patient.columns)

# %%
coad_total = pd.merge(patient, tcga_c[tcga_m], left_index=True, right_index=True, how='outer')
display(coad_total)
# Out:
#                                          bcr_patient_uuid  ... tumor_status
# bcr_patient_barcode                                        ...
# TCGA-3L-AA1B         A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...   TUMOR FREE
# TCGA-4N-A93T         92554413-9EBC-4354-8E1B-9682F3A031D9  ...   WITH TUMOR
# TCGA-4T-AA8H         A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...   TUMOR FREE
# TCGA-5M-AAT4         1136DD50-242A-4659-AAD4-C53F9E759BB3  ...   WITH TUMOR
# TCGA-5M-AAT6         CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...   WITH TUMOR
# ...                                                   ...  ...          ...
# TCGA-QL-A97D         D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...   TUMOR FREE
# TCGA-RU-A8FL         5F6ED48B-3B5A-4D20-8FBF-C9AA3FEEA186  ...   WITH TUMOR
# TCGA-SS-A7HO         8D0FA506-3F51-4108-8427-7DABF270BCD4  ...   WITH TUMOR
# TCGA-T9-A92H         81A7184E-F9F5-4E3F-9603-5F5642386C1E  ...   WITH TUMOR
# ...

# %%
coad_total1 = pd.merge(patient, tcga_c, how='inner', on='bcr_patient_barcode')
display(coad_total1)
#중복행 3개였음
# Out:
#                                          bcr_patient_uuid  ... PFI.time
# bcr_patient_barcode                                        ...
# TCGA-3L-AA1B         A94E1279-A975-480A-93E9-7B1FF05CBCBF  ...    475.0
# TCGA-4N-A93T         92554413-9EBC-4354-8E1B-9682F3A031D9  ...    146.0
# TCGA-4T-AA8H         A5E14ADD-1552-4606-9FFE-3A03BCF76640  ...    385.0
# TCGA-5M-AAT4         1136DD50-242A-4659-AAD4-C53F9E759BB3  ...     49.0
# TCGA-5M-AAT6         CE00896A-F7D2-4123-BB95-24CB6E53FC32  ...    219.0
# ...                                                   ...  ...      ...
# TCGA-QL-A97D         D5A1F43E-25A7-47F5-B63E-43714F9F732A  ...    666.0
# TCGA-RU-A8FL         5F6ED48B-3B5A-4D20-8FBF-C9AA3FEEA186  ...    256.0
# TCGA-SS-A7HO         8D0FA506-3F51-4108-8427-7DABF270BCD4  ...    506.0
# TCGA-T9-A92H         81A7184E-F9F5-4E3F-9603-5F5642386C1E  ...     81.0
# TCGA-WS-AB45         7F6898E2-A840-4AD1-80F7-783F8B766FCC  ...   2130.0
#
# [459 rows x 88 columns]
